# %%
from booknlp.booknlp import BookNLP
import os
# Out:
# using device cpu

# %%
#define booknlp model
model_params={
    "pipeline":"entity", 
    "model":"small"
}

booknlp=BookNLP("en", model_params)
# Out:
# {'pipeline': 'entity', 'model': 'small'}
# --- startup: 1.288 seconds ---

# %%
#directory
all_files = 'input_dir/scwared-14-sample-dataset'

# %%
# set lists
input_dir=[]
output_directory=[]
book_id = []

# %%
for subdir in os.listdir(all_files):
    d = {}
    filenames = []

    for filename in os.listdir(os.path.join(all_files, subdir)):

        if filename.endswith('.txt'):
            with open(os.path.join(all_files, subdir, filename), 'r') as f:

                d.update({os.path.splitext(filename[-7:])[0]: f.read()})
        
        input_dir.append(all_files + "/" + subdir +"/"+ filename)

        output_directory.append("output_dir/" + subdir +"|"+ os.path.splitext(filename[-7:])[0])
        book_id.append(subdir +"|"+ os.path.splitext(filename[-7:])[0])

# %%
print(input_dir)
# Out:
# ['input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000106.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000073.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000071.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000111.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000064.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000070.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000074.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000060.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000100.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000101.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000088.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000102.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000116.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000089.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000207.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000159.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000166.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000200.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000214.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000148.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000160.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000150.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000187.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000192.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000151.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000147.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000153.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000152.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000142.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000156.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000141.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000182.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000168.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000084.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000085.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000078.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000093.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000079.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000081.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015046352020/00000080.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015040730916/00000064.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015040730916/00000038.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015040730916/00000024.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015040730916/00000025.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015040730916/00000034.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015040730916/00000053.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015040730916/00000046.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015040730916/00000055.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015040730916/00000068.txt', 'input_dir/scwared-14-sample-dataset/mdp.39015040730916/00000056.txt', 'input_dir/scwared-14-sample-dataset/mdp.39076001498182/00000107.txt', 'input_dir/scwared-14-sample-dataset/mdp.39076001498182/00000113.txt', 'input_dir/scwared-14-sample-dataset/mdp.39076001498182/00000071.txt', 'input_dir/scwared-14-sample-dataset/mdp.39076001498182/00000139.txt', 'input_dir/scwared-14-sample-dataset/mdp.39076001498182/00000064.txt', 'input_dir/scwared-14-sample-dataset/mdp.39076001498182/00000074.txt', 'input_dir/scwared-14-s ...

# %%
for i in range(len(input_dir)):
    booknlp.process(input_dir[i], output_directory[i], book_id[i])
